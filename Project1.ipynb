# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('C:\\Users\\kevin\\Project.xlsx')

# %%
# Preprocessing the Data

# %%
df
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  44963     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  45083     235
# 2     John Holland  Boston Celtics      30       SG   27  45052     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  45052     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  45205     231
# ..             ...             ...     ...      ...  ...    ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  44991     203
# 454      Raul Neto       Utah Jazz      25       PG   24  44932     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  44992     256
# 456    Jeff Withey       Utah Jazz      24        C   26    7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  44992     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
print(df.dtypes)
# Out:
# Name         object
# Team         object
# Number        int64
# Position     object
# Age           int64
# Height        int32
# Weight        int64
# College      object
# Salary      float64
# dtype: object

# %%
#  Correcting the "Height" Column with Random Values

# %%
df['Height'] = pd.to_numeric(df['Height'], errors='coerce')

# %%
np.random.seed(42)  
df['Height'] = np.random.randint(150, 181, df.shape[0])

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     156     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     169     235
# 2     John Holland  Boston Celtics      30       SG   27     178     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     164     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     160     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     168     203
# 454      Raul Neto       Utah Jazz      25       PG   24     153     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     152     256
# 456    Jeff Withey       Utah Jazz      24        C   26     166     231
# 457       Priyanka       Utah Jazz      34        C   25     166     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
#  Handle Missing Data

# %%
print(df.isnull().sum())
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
df['College'] = df['College'].fillna('Unknown')

# %%
df['Salary'] = df['Salary'].fillna(df['Salary'].median())

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     156     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     169     235
# 2     John Holland  Boston Celtics      30       SG   27     178     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     164     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     160     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     168     203
# 454      Raul Neto       Utah Jazz      25       PG   24     153     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     152     256
# 456    Jeff Withey       Utah Jazz      24        C   26     166     231
# 457       Priyanka       Utah Jazz      34        C   25     166     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# ANALYSIS TASKS AND VISUALISATIONS

# %%
# 1.Employee Distribution Across Teams

# %%
team_counts = df['Team'].value_counts()

# %%
team_counts
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
team_percentage = (team_counts / len(df)) * 100

# %%
team_percentage
# Out:
# Team
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Golden State Warriors     3.275109
# Toronto Raptors           3.275109
# ...

# %%
plt.figure(figsize=(8,5))
team_counts.plot(kind='bar', color='skyblue')
plt.title("Employee Distribution Across Teams")
plt.xlabel("Teams")
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The dataset provides a breakdown of employees across various teams. The number of employees per team varies slightly, but most teams have between 14 to 19 employees.
#  Key Observations:
# 1.New Orleans Pelicans has the highest number of employees (19 employees).
# 2.Memphis Grizzlies follows with 18 employees.
# 3.Most teams have 15 employees, indicating a balanced distribution.
# 4.The teams with the lowest count (14 employees) are Orlando Magic and Minnesota Timberwolves.

# %%
# 2.Segregation of Employees by Position

# %%
position_counts = df['Position'].value_counts()

# %%
position_counts
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
position_counts.plot(kind='bar', color='orange')
plt.title("Employee Count by Position")
plt.xlabel("Position")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The dataset categorizes employees into five main positions:
# Shooting Guards (SG) have the highest number of employees (102 employees).
# Power Forwards (PF) and Point Guards (PG) also have a significant presence, with 100 and 92 employees respectively.
# Small Forwards (SF) account for 85 employees , making them the second least common position.
# Centers (C) have the fewest employees, with only 79 .

# %%
# 3.Predominant Age Group Among Employees

# %%
bins = [20, 30, 40, 50, 60]  
labels = ['20-30', '30-40', '40-50', '50-60']
df['Age Group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)

# %%
age_group_counts = df['Age Group'].value_counts()

# %%
age_group_counts
# Out:
# Age Group
# 20-30    334
# 30-40    119
# 40-50      3
# 50-60      0
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,5))
age_group_counts.plot(kind='bar', color='green')
plt.title("Predominant Age Group")
plt.xlabel("Age Group")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# The employees in the dataset are distributed across four distinct age groups:
# The 20-30 age group represents the vast majority of employees, with 334 employees.
# The 30-40 age group comes next, with 119 employees .
# The 40-50 and 50-60 age groups have significantly fewer employees, with only 3 employees in the 40-50 group and no employees in the 50-60 group.

# %%
# 4.Highest Salary Expenditure by Team and Position

# %%
team_salary = df.groupby('Team')['Salary'].sum().sort_values(ascending=False)

# %%
team_salary
# Out:
# Team
# Cleveland Cavaliers       109824875.0
# Los Angeles Clippers       94854640.0
# Oklahoma City Thunder      93765298.0
# Golden State Warriors      88868997.0
# Miami Heat                 88188045.0
# Memphis Grizzlies          87895624.0
# Chicago Bulls              86783378.0
# San Antonio Spurs          84442733.0
# New Orleans Pelicans       82750774.0
# Charlotte Hornets          78340920.0
# Washington Wizards         76328636.0
# Houston Rockets            75283021.0
# New York Knicks            73303898.0
# Atlanta Hawks              72902950.0
# Los Angeles Lakers         71770431.0
# Sacramento Kings           71683666.0
# Dallas Mavericks           71198732.0
# Toronto Raptors            71117611.0
# Milwaukee Bucks            69603517.0
# Detroit Pistons            67168263.0
# Indiana Pacers             66751826.0
# Utah Jazz                  64007367.0
# Phoenix Suns               63445135.0
# Denver Nuggets             62958116.0
# ...

# %%
position_salary = df.groupby('Position')['Salary'].sum().sort_values(ascending=False)

# %%
position_salary
# Out:
# Position
# C     466377332.0
# PG    458193715.0
# PF    451069408.0
# SF    410857162.0
# SG    405484816.0
# Name: Salary, dtype: float64

# %%
team_salary_percentage = team_salary / team_salary.sum() * 100

# %%
team_salary_percentage
# Out:
# Team
# Cleveland Cavaliers       5.010299
# Los Angeles Clippers      4.327345
# Oklahoma City Thunder     4.277648
# Golden State Warriors     4.054275
# Miami Heat                4.023209
# Memphis Grizzlies         4.009869
# Chicago Bulls             3.959127
# San Antonio Spurs         3.852345
# New Orleans Pelicans      3.775157
# Charlotte Hornets         3.573976
# Washington Wizards        3.482174
# Houston Rockets           3.434472
# New York Knicks           3.344183
# Atlanta Hawks             3.325891
# Los Angeles Lakers        3.274225
# Sacramento Kings          3.270266
# Dallas Mavericks          3.248143
# Toronto Raptors           3.244443
# Milwaukee Bucks           3.175368
# Detroit Pistons           3.064270
# Indiana Pacers            3.045272
# Utah Jazz                 2.920068
# Phoenix Suns              2.894418
# Denver Nuggets            2.872200
# Minnesota Timberwolves    2.853393
# Boston Celtics            2.800080
# ...

# %%
plt.figure(figsize=(7,7))
team_salary_percentage.plot(kind='pie', autopct='%1.1f%%')
plt.title("Salary Distribution per Team")
plt.ylabel('')  
plt.show()

# %% [markdown]
# We first group the salary data by teams and sum up the total salary for each one. This helps us understand which department or unit has the highest salary expenditure
# Key Insight:
#
# The team with the highest total salary expenditure is is Cleveland Cavaliers with total salary 109824875.0, followed by Los Angeles Clippers and Oklahoma City Thunder.

# %%
position_salary_percentage = position_salary / position_salary.sum() * 100

# %%
position_salary_percentage
# Out:
# Position
# C     21.276509
# PG    20.903165
# PF    20.578149
# SF    18.743634
# SG    18.498543
# Name: Salary, dtype: float64

# %%
plt.figure(figsize=(7,7))
position_salary_percentage.plot(kind='pie', autopct='%1.1f%%')
plt.title("Salary Distribution per Position")
plt.ylabel('') 
plt.show()

# %% [markdown]
# We analyze salary distribution based on  positions. By grouping salaries by titles and summing them up, we determine which role incurs the highest salary costs.
#
# Key Insight:
# Centers (C) receive the highest salary expenditure (21.28%)
# Point Guards (PG) are the second highest-paid position (20.90%)
# Shooting Guards (SG) have the lowest total salary allocation (18.50%)

# %%
# 5.Correlation Between Age and Salary

# %%
correlation_matrix = df[['Age', 'Salary']].corr()

# %%
correlation_matrix
# Out:
#              Age    Salary
# Age     1.000000  0.209124
# Salary  0.209124  1.000000

# %%
plt.figure(figsize=(6,5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Matrix: Age vs Salary")
plt.show()

# %% [markdown]
# A correlation matrix provides a numerical representation of relationships between variables. Since we are focusing on the correlation between Age and Salary, we extract relevant insights from the matrix.
# The correlation coefficient between Age and Salary is 0.209, indicating a weak positive correlation.
